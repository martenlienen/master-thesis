# %%
import matplotlib.patches as mp
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
fig = pp.figure(figsize=(6, 3), dpi=200)
ax = fig.add_axes([0, 0, 1, 1])
ax.axis("off")

ls = ax.annotate("Label\nSequence", xy=(0.3, 0.1), xycoords="figure fraction", ha="center", va="center")
fc = ax.annotate("Framewise\nClassifications", xy=(0.7, 0.1), xycoords="figure fraction", ha="center", va="center")
gists = ax.annotate("Gists", xy=(0.51, 0.6), xycoords="figure fraction", ha="center", va="center")
iv3 = ax.annotate("InceptionV3\nFeatures", xy=(0.82, 0.6), xycoords="figure fraction", ha="center", va="center")
rf = ax.annotate("Reconstructed\nFrames", xy=(0.5, 0.85), xycoords="figure fraction", ha="center", va="center")
pe = ax.annotate("Preprocessed\nEvents", xy=(0.18, 0.6), xycoords="figure fraction", ha="center", va="center")

# PE -> RF
ax.text(0.23, 0.82, "dvs-reconstruction", size=7, rotation=27, color="0.3",
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.14, 0.65), posB=(0.4, 0.87),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=45,angleB=180",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# RF -> IV3
ax.text(0.73, 0.82, "inceptionv3", size=7, rotation=-27, color="0.3", 
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.57, 0.87), posB=(0.82, 0.65),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=0,angleB=135",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# PE -> gists
ax.text(0.28, 0.61, "autoencoder", size=7, color="0.3", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.21, 0.59), posB=(0.46, 0.59),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# PE -> LS
ax.text(0.174, 0.26, "GRU+CTC", size=7, color="0.3", rotation=-74,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.14, 0.54), posB=(0.22, 0.03),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-90,angleB=135",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# PE -> FC
ax.text(0.3, 0.39, "GRU+CE", size=7, color="0.3", rotation=-35,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.18, 0.54), posB=(0.645, 0.045),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-40,angleB=-10",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# FC -> LS
ax.text(0.5, 0.045, "HMM decoder", size=7, color="0.3", va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.62, 0.02), posB=(0.315, 0.02),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# gists -> LS
ax.text(0.44, 0.39, "GRU+CTC", size=7, color="0.3", rotation=51,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.5, 0.54), posB=(0.3, 0.05),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-90,angleB=45",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# gists -> CF
ax.text(0.56, 0.39, "GRU+CE", size=7, color="0.3", rotation=-51,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.5, 0.54), posB=(0.7, 0.05),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-90,angleB=135",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# iv3 -> LS
ax.text(0.68, 0.38, "GRU+CTC", size=7, color="0.3", rotation=39,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.78, 0.54), posB=(0.31, 0.035),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-130,angleB=10",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# iv3 -> CF
ax.text(0.795, 0.26, "GRU+CE", size=7, color="0.3", rotation=80,
        va="center", ha="center", transform=fig.transFigure)
ax.add_patch(mp.FancyArrowPatch(posA=(0.82, 0.54), posB=(0.77, 0.03),
                                arrowstyle="fancy", fc="0.6", ec="none", alpha=0.5,
                                connectionstyle="angle3,angleA=-90,angleB=45",
                                shrinkA=0, shrinkB=0,
                                mutation_scale=10, transform=fig.transFigure))

# Feature Extraction box
ax.text(0.08, 0.96, "Feature Extraction", size=7, color="0.3", transform=fig.transFigure)
ax.add_patch(mp.FancyBboxPatch((0.05, 0.53), 0.87, 0.41,
                               boxstyle="round,pad=0.01,rounding_size=0.03",
                               ls="dashed", fill=False, ec="0.7",
                               transform=fig.transFigure))

# %%
fig.savefig("../doc/figures/methods/overview.pdf", bbox_inches="tight")
